# %% [markdown]
# # Import Libraries

# %%
import pandas as pd

# %% [markdown]
# # Dataframe

# %% [markdown]
# ## Read .csv and create dataframe

# %%
file_path = '/home/chad/code/ChadReich/solar_PV_forecaster/Le Wagon Solar Data.csv'

# Read the CSV file into a Pandas DataFrame
df = pd.read_csv(file_path)

# Select only relevant columns from .csv
selected_columns = ['meter_id', 'tstamp', 'impwh', 'expwh', 'ptot']
new_df = df[selected_columns]

# %% [markdown]
# ## Format dataframe

# %%
new_df['ptot'] = new_df['ptot'].abs()

# Select rows of only one meter using its meter_id
df_final = new_df[new_df['meter_id'] == 7672]

# Convert the object column to datetime
df_final['tstamp'] = pd.to_datetime(df_final['tstamp'])

# Set the timestamp column as the DataFrame index
df_final.set_index('tstamp', inplace=True)

# Resample with a frequency of 1 minute and fill gaps with 0
df_final = df_final.resample('5T').sum().fillna(0)

# Remove specific rows at beginning of df
start_timestamp = pd.Timestamp('2020-11-28 08:25')
end_timestamp = pd.Timestamp('2020-11-28 23:55')

# Create a boolean mask to filter rows between the start and end timestamps
mask = (df_final.index < start_timestamp) | (df_final.index > end_timestamp)

# Apply the mask to the DataFrame to remove rows between the two timestamps
df_f = df_final[mask]

df_f
# Out:
# /tmp/ipykernel_12681/3039913987.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['ptot'] = new_df['ptot'].abs()
# /tmp/ipykernel_12681/3039913987.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['tstamp'] = pd.to_datetime(df_final['tstamp'])
#                      meter_id      impwh         expwh     ptot
# tstamp
# 2020-11-29 00:00:00      7672    7363.04  1.612240e+08    0.000
# 2020-11-29 00:05:00      7672    7363.04  1.612240e+08    0.000
# 2020-11-29 00:10:00      7672    7363.04  1.612240e+08    0.000
# 2020-11-29 00:15:00      7672    7363.04  1.612240e+08    0.000
# 2020-11-29 00:20:00      7672    7363.04  1.612240e+08    0.000
# ...                       ...        ...           ...      ...
# 2023-11-28 03:45:00      7672  101261.92  2.211862e+09  100.988
# 2023-11-28 03:50:00      7672  101261.92  2.211870e+09   93.512
# 2023-11-28 03:55:00      7672  101261.92  2.211876e+09   77.631
# 2023-11-28 04:00:00      7672  101261.92  2.211882e+09   72.378
# 2023-11-28 04:05:00      7672  101261.92  2.211890e+09   95.303
#
# [315122 rows x 4 columns]

# %%
df_f=df_f[(df_f.index.hour>=5) & (df_f.index.hour<=20)]

# %% [markdown]
# ## Create a label column for specified events

# %%
# Replace 'value_column' with the actual name of the column containing 0 values
ptot = 'ptot'

# Calculate the rolling sum of 0 values over a 5-minute window (12 points per hour)
rolling_sum = df_f[ptot].eq(0).rolling(window=12).sum()
rolling_sum
# Out:
# tstamp
# 2020-11-29 05:00:00     NaN
# 2020-11-29 05:05:00     NaN
# 2020-11-29 05:10:00     NaN
# 2020-11-29 05:15:00     NaN
# 2020-11-29 05:20:00     NaN
#                        ...
# 2023-11-27 20:35:00    12.0
# 2023-11-27 20:40:00    12.0
# 2023-11-27 20:45:00    12.0
# 2023-11-27 20:50:00    12.0
# 2023-11-27 20:55:00    12.0
# Name: ptot, Length: 210048, dtype: float64

# %%
df_f["rolling_sum"]=rolling_sum
# Out:
# /tmp/ipykernel_12681/1614791040.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_f["rolling_sum"]=rolling_sum

# %%
rolling_sum.value_counts()
# Out:
# 0.0     118214
# 12.0     48829
# 1.0       9626
# 2.0       5020
# 11.0      3659
# 3.0       3490
# 4.0       3141
# 6.0       3119
# 5.0       3043
# 10.0      3001
# 9.0       2975
# 7.0       2971
# 8.0       2949
# Name: ptot, dtype: int64

# %%
# Create a new column
df_f['Power loss event'] = 1# Default value
df_f
# Out:
# /tmp/ipykernel_12681/1139721742.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_f['Power loss event'] = 1# Default value
#                      meter_id      impwh         expwh   ptot  rolling_sum  \
# tstamp
# 2020-11-29 05:00:00      7672    7363.04  1.612240e+08  0.000          NaN
# 2020-11-29 05:05:00      7672    7363.04  1.612240e+08  0.000          NaN
# 2020-11-29 05:10:00      7672    7363.04  1.612240e+08  0.000          NaN
# 2020-11-29 05:15:00      7672    7363.04  1.612241e+08  1.164          NaN
# 2020-11-29 05:20:00      7672    7363.04  1.612243e+08  2.127          NaN
# ...                       ...        ...           ...    ...          ...
# 2023-11-27 20:35:00      7672  101261.92  2.211767e+09  0.000         12.0
# 2023-11-27 20:40:00      7672  101261.92  2.211767e+09  0.000         12.0
# 2023-11-27 20:45:00      7672  101261.92  2.211767e+09  0.000         12.0
# 2023-11-27 20:50:00      7672  101261.92  2.211767e+09  0.000         12.0
# 2023-11-27 20:55:00      7672  101261.92  2.211767e+09  0.000         12.0
#
#                      Power loss event
# tstamp
# 2020-11-29 05:00:00                 1
# 2020-11-29 05:05:00                 1
# 2020-11-29 05:10:00                 1
# 2020-11-29 05:15:00                 1
# 2020-11-29 05:20:00                 1
# ...                               ...
# 2023-11-27 20:35:00                 1
# 2023-11-27 20:40:00                 1
# 2023-11-27 20:45:00                 1
# 2023-11-27 20:50:00                 1
# 2023-11-27 20:55:00                 1
#
# [210048 rows x 6 columns]

# %%
df_f["Power loss event"].value_counts()
# Out:
# 1    210048
# Name: Power loss event, dtype: int64

# %%
# Set rows with no 0 values in Ptot to 0 (i.e. no power loss)
df_f.loc[df_f["rolling_sum"] != 0, 'Power loss event'] = 0
df_f["Power loss event"]
# Out:
# tstamp
# 2020-11-29 05:00:00    0
# 2020-11-29 05:05:00    0
# 2020-11-29 05:10:00    0
# 2020-11-29 05:15:00    0
# 2020-11-29 05:20:00    0
#                       ..
# 2023-11-27 20:35:00    0
# 2023-11-27 20:40:00    0
# 2023-11-27 20:45:00    0
# 2023-11-27 20:50:00    0
# 2023-11-27 20:55:00    0
# Name: Power loss event, Length: 210048, dtype: int64

# %%
df_f["Power loss event"].value_counts()
# Out:
# 1    118214
# 0     91834
# Name: Power loss event, dtype: int64

# %%
df_f["rolling_sum"].value_counts()
# Out:
# 0.0     118214
# 12.0     48829
# 1.0       9626
# 2.0       5020
# 11.0      3659
# 3.0       3490
# 4.0       3141
# 6.0       3119
# 5.0       3043
# 10.0      3001
# 9.0       2975
# 7.0       2971
# 8.0       2949
# Name: rolling_sum, dtype: int64

# %%
df_f[:360]
# Out:
#                      meter_id    impwh        expwh    ptot  rolling_sum  \
# tstamp
# 2020-11-29 05:00:00      7672  7363.04  161224025.0   0.000          NaN
# 2020-11-29 05:05:00      7672  7363.04  161224025.0   0.000          NaN
# 2020-11-29 05:10:00      7672  7363.04  161224025.0   0.000          NaN
# 2020-11-29 05:15:00      7672  7363.04  161224121.9   1.164          NaN
# 2020-11-29 05:20:00      7672  7363.04  161224299.2   2.127          NaN
# ...                       ...      ...          ...     ...          ...
# 2020-11-30 18:35:00      7672  7469.92  167139066.2  31.905          0.0
# 2020-11-30 18:40:00      7672  7469.92  167141731.2  31.980          0.0
# 2020-11-30 18:45:00      7672  7469.92  167143672.0  23.212          0.0
# 2020-11-30 18:50:00      7672  7469.92  167145252.8  19.033          0.0
# 2020-11-30 18:55:00      7672  7469.92  167146154.1  10.815          0.0
#
#                      Power loss event
# tstamp
# 2020-11-29 05:00:00                 0
# 2020-11-29 05:05:00                 0
# 2020-11-29 05:10:00                 0
# 2020-11-29 05:15:00                 0
# 2020-11-29 05:20:00                 0
# ...                               ...
# 2020-11-30 18:35:00                 1
# 2020-11-30 18:40:00                 1
# 2020-11-30 18:45:00                 1
# 2020-11-30 18:50:00                 1
# 2020-11-30 18:55:00                 1
#
# [360 rows x 6 columns]

# %%
df_f[:300].plot(y="rolling_sum")
# Out:
# <AxesSubplot:xlabel='tstamp'>

# %%
# Set rows with 0 values totaling less than 2 hours but more than 4.5 hours to 2
df_f.loc[(rolling_sum <= 24) & (rolling_sum >= 54), 'Power loss event'] = 2

# Set rows with 0 values totaling between 2 hours and 4.5 hours to 0
df_f.loc[(rolling_sum > 24) & (rolling_sum < 54), 'Power loss event'] = 1

df_f.head(60)
# Out:
#                      meter_id    impwh        expwh     ptot  rolling_sum  \
# tstamp
# 2020-11-29 05:00:00      7672  7363.04  161224025.0    0.000          NaN
# 2020-11-29 05:05:00      7672  7363.04  161224025.0    0.000          NaN
# 2020-11-29 05:10:00      7672  7363.04  161224025.0    0.000          NaN
# 2020-11-29 05:15:00      7672  7363.04  161224121.9    1.164          NaN
# 2020-11-29 05:20:00      7672  7363.04  161224299.2    2.127          NaN
# 2020-11-29 05:25:00      7672  7363.04  161224579.4    3.351          NaN
# 2020-11-29 05:30:00      7672  7363.04  161225004.2    5.115          NaN
# 2020-11-29 05:35:00      7672  7363.04  161225636.8    7.592          NaN
# 2020-11-29 05:40:00      7672  7363.04  161226553.1   10.959          NaN
# 2020-11-29 05:45:00      7672  7363.04  161227806.4   15.090          NaN
# 2020-11-29 05:50:00      7672  7363.04  161229479.7   20.013          NaN
# 2020-11-29 05:55:00      7672  7363.04  161231593.0   25.444          3.0
