# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, GridSearchCV, TimeSeriesSplit, cross_val_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import SelectFromModel
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("/home/chad/code/ChadReich/solar_PV_forecaster/solar_project_data.csv")

# %%
df
# Out:
#                      tstamp  meter_id      impwh         expwh  ptot  \
# 0       2020-11-29 05:00:00      5884      59.68  1.183848e+09   0.0
# 1       2020-11-29 05:05:00      5884      59.68  1.183848e+09   0.0
# 2       2020-11-29 05:10:00      5884      59.68  1.183848e+09   0.0
# 3       2020-11-29 05:15:00      5884      59.68  1.183848e+09   0.0
# 4       2020-11-29 05:20:00      5884      59.68  1.183848e+09   0.0
# ...                     ...       ...        ...           ...   ...
# 626012  2023-11-27 19:40:00      7672  101261.92  2.211767e+09   0.0
# 626013  2023-11-27 19:45:00      7672  101261.92  2.211767e+09   0.0
# 626014  2023-11-27 19:50:00      7672  101261.92  2.211767e+09   0.0
# 626015  2023-11-27 19:55:00      7672  101261.92  2.211767e+09   0.0
# 626016  2023-11-27 20:00:00      7672  101261.92  2.211767e+09   0.0
#
#         Power Loss Event  AirTemp  Azimuth  CloudOpacity  DewpointTemp  Dhi  \
# ...

# %%
# Convert the object column to datetime
df['tstamp'] = pd.to_datetime(df['tstamp'])

# Set the timestamp column as the DataFrame index
df.set_index('tstamp', inplace=True)

# %%
df['ptot'].describe()
# Out:
# count    626017.000000
# mean        127.825101
# std         128.111973
# min           0.000000
# 25%           6.929000
# 50%          93.814000
# 75%         214.971000
# max         824.883000
# Name: ptot, dtype: float64

# %%
plt.figure(figsize = (10, 6))
plt.scatter(range(df.shape[0]), np.sort(df['ptot'].values))
plt.xlabel('index')
plt.ylabel('y')
plt.title("Time Distribution")
plt.show();

# %%
cols = [c for c in df.columns if 'e' or 'i' in c]
print('Number of features except ID and target feature: {}'.format(len(cols)))
print('Feature types :')
df[cols].dtypes.value_counts()
# Out:
# Number of features except ID and target feature: 17
# Feature types :
# float64    9
# int64      8
# dtype: int64

# %%
if df.isnull().values.any():
    print("DataFrame has missing values.")
else:
    print("DataFrame does not have missing values.")
# Out:
# DataFrame does not have missing values.
